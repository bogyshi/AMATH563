# %%
# %matplotlib notebook
# %matplotlib inline

from scipy import integrate
import numpy as np
import matplotlib.pyplot as plt
import scipy as sc
from mpl_toolkits.mplot3d import axes3d, Axes3D
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import Perceptron
import os
N=256

# %%
def predictKSEQ(clf,initPoint,numSteps,N):
    res = initPoint
    counter = 0
    result = np.zeros([numSteps,N])
    while(counter<numSteps):
        res = clf.predict(res)
        result[counter,:]=res
        counter+=1
    return result

# %%
def printNNInfo(clft):
    print('Num Iters: ' + str(clft.n_iter_))
    print('numLayers: ' + str(clft.n_layers_))
    print('Num outputs: '+str(clft.n_outputs_))
    print('activation layer: ' + str(clft.out_activation_))
    print('Loss: ' + str(clft.loss_))

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

def KSEQData(N=128,udivFactor=16):

    # Kuramoto-Sivashinsky equation (from Trefethen)
    # u_t = -u*u_x - u_xx - u_xxxx,  periodic BCs 

    x = 32*np.pi*np.arange(1,N+1)/N;
    u = np.cos(x/udivFactor)*(1+np.sin(x/udivFactor)); #THIS IS THE INITIAL CONDITION
    v = np.fft.fft(u);

    #Spatial grid and initial condition:
    h = 0.025;
    k = np.concatenate([np.arange(0,N/2),[0],np.arange(-N/2+1,0)])/16;
    L = k**2 - k**4;
    E = np.exp(h*L); E2 = np.exp(h*L/2);
    M = 16;
    r = np.exp(1j*np.pi*(np.arange(1,M+1)-.5)/M)
    LR = h*np.tile(L,(M,1)).T + np.tile(r,(N,1)) 
    # tile repeats an array the number of times specified in whichever type of axis (M repeats on 1 columnar.)
    Q = h*np.real(np.mean( (np.exp(LR/2)-1)/LR, axis=1)); 
    f1 = h*np.real(np.mean( (-4-LR+np.exp(LR)*(4-3*LR+LR**2))/LR**3, axis=1)); 
    f2 = h*np.real(np.mean( (2+LR+np.exp(LR)*(-2+LR))/LR**3, axis=1));
    f3 = h*np.real(np.mean( (-4-3*LR-LR**2+np.exp(LR)*(4-LR))/LR**3, axis=1));

    # Main time-stepping loop:
    uu = u; tt = 0;
    tmax = 100; nmax = round(tmax/h); nplt = np.floor((tmax/250)/h); g = -0.5j*k;
    for n in range(1,nmax+1):
        t = n*h;
        Nv = g*np.fft.fft(np.real(np.fft.ifft(v))**2);
        a = E2*v + Q*Nv;
        Na = g*np.fft.fft(np.real(np.fft.ifft(a))**2);
        b = E2*v + Q*Na;
        Nb = g*np.fft.fft(np.real(np.fft.ifft(b))**2);
        c = E2*a + Q*(2*Nb-Nv);
        Nc = g*np.fft.fft(np.real(np.fft.ifft(c))**2);
        v = E*v + Nv*f1 + 2*(Na+Nb)*f2 + Nc*f3; 
        if np.mod(n,nplt)==0:
            u = np.real(np.fft.ifft(v));
            uu = np.vstack([uu,u]); tt = np.append(tt,t);

    # Plot results:
    plt.figure()
    plt.pcolormesh(uu)
    plt.show()
    return uu
    

uu = KSEQData(N,udivFactor=16)

# %%
# Out:
# (251, 256)

# %%
divTrains = [12,15,16,17,19]
numEntries = len(divTrains)
stepSize = uu.shape[0]
counter = 0
rawDataKSEQ = np.zeros([stepSize * numEntries,N])
for d in divTrains:
    print(d)
    rawDataKSEQ[(counter*stepSize):((counter+1)*stepSize),:] = KSEQData(N,udivFactor=d)
    counter+=1
# Out:
# 12
# 15
# 16
# 17
# 19

# %% [markdown]
# create like 10 more datasets with different initial conditions spanning a range to give it more to work with

# %%
x-uu[0:]
# Out:
# array([[24.30198899, 24.25706313, 24.21547417, ..., 24.45215345,
#         24.40000613, 24.34979301],
#        [24.32494643, 24.27922221, 24.23638841, ..., 24.47508966,
#         24.42331769, 24.37312435],
#        [24.34783857, 24.30161491, 24.25787141, ..., 24.4973349 ,
#         24.44609904, 24.39613445],
#        ...,
#        [26.97000417, 26.68758138, 25.70807185, ..., 24.28993975,
#         25.00812126, 26.24549209],
#        [26.82461116, 26.44396789, 25.48923008, ..., 24.55913852,
#         25.25151384, 26.30580303],
#        [26.63883902, 26.17488141, 25.28150213, ..., 24.86746038,
#         25.49586288, 26.33215964]])

# %% [markdown]
# ## seperating data

# %%
dataIn = rawDataKSEQ[0:-1]
dataOut = rawDataKSEQ[1:]
print(dataIn.shape)
print(dataOut.shape)
# Out:
# (1254, 256)
# (1254, 256)

# %% [markdown]
# ## Fitting a model

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import Perceptron

#clf = MLPRegressor(hidden_layer_sizes=N,solver='sgd', activation = 'relu',alpha=1e-6,
#                  max_iter=10000)
#clf = MLPRegressor(hidden_layer_sizes=[N,(N*2),N],solver='sgd', activation = 'relu',alpha=1e-4,learning_rate='adaptive',
 #                max_iter=10000)
if(os.path.isfile('data/weightsKS.npy')):
    clf = np.load('data/weightsKS.npy').flatten()[0]
else:
    clf = MLPRegressor(hidden_layer_sizes=(N*2,N*3,N*2), activation = 'relu',alpha=1e-4,learning_rate='adaptive',
                 max_iter=10000,random_state=123)
    clf.fit(dataIn,dataOut)
    np.save('data/weightsKS',clf)
# Out:
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(512, 768, 512), learning_rate='adaptive',
#        learning_rate_init=0.001, max_iter=10000, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=123, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
printNNInfo(clf)
# Out:
# Num Iters: 66
# numLayers: 5
# Num outputs: 256
# activation layer: identity
# Loss: 0.004258866655204098

# %%
firstPoint = np.reshape(dataIn[0],(1,-1))

# %% [markdown]
# ## predicting

# %%
result = predictKSEQ(clf,firstPoint,stepSize,N)
plt.figure()
plt.pcolormesh(result)
plt.show()

# %% [markdown]
# ## Exercise 1b: new conditions

# %%
newStuff = np.array(divTrains)+1
for div in newStuff:
    newData = KSEQData(N,udivFactor=div)
    newFirstPoint = np.reshape(newData[0],(1,-1))
    newResult = predictKSEQ(clf,newFirstPoint,newData.shape[0]-1,N)
    plt.clf()
    plt.figure()
    plt.pcolormesh(newResult)
    plt.show()

# %% [markdown]
# ## Exercise 1C: reaction diffusion predictions
# getting data

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
import numpy as np
from scipy import integrate
import matplotlib.pyplot as plt

def getRDData():
    def reaction_diffusion_rhs(t,uvt,K22,d1,d2,beta,n,N):
        # Calculate u and v terms
        ut=np.reshape(uvt[:N],(n,n));
        vt=np.reshape(uvt[N:],(n,n));
        u=np.real(np.fft.ifft2(ut)); v=np.real(np.fft.ifft2(vt));

        # Reaction Terms
        u3=u**3; v3=v**3; u2v=(u**2)*v; uv2=u*(v**2);
        utrhs=np.reshape(np.fft.fft2(u-u3-uv2+beta*u2v+beta*v3),(N,1));
        vtrhs=np.reshape(np.fft.fft2(v-u2v-v3-beta*u3-beta*uv2),(N,1));

        return np.concatenate([-d1*K22*uvt[:N]+utrhs, -d2*K22*uvt[N:]+vtrhs])[:,0]

    # lambda-omega reaction-diffusion system
    #  u_t = lam(A) u - ome(A) v + d1*(u_xx + u_yy) = 0
    #  v_t = ome(A) u + lam(A) v + d2*(v_xx + v_yy) = 0
    #
    #  A^2 = u^2 + v^2 and
    #  lam(A) = 1 - A^2
    #  ome(A) = -beta*A^2


    t=np.linspace(0,10,201);
    d1=0.1; d2=0.1; beta=1.0;
    L=20; n=32; N=n*n;
    x2=np.linspace(-L/2,L/2,n+1); x=x2[0:n]; y=x;
    kx=(2*np.pi/L)*np.concatenate([np.arange(0,n/2), np.arange(-n/2,0)]); ky=kx;

    # INITIAL CONDITIONS

    [X,Y]=np.meshgrid(x,y);
    [KX,KY]=np.meshgrid(kx,ky);
    K2=KX**2+KY**2; K22=np.reshape(K2,(N,1));

    m=1; # number of spirals

    u = np.zeros((len(x),len(y),len(t)));
    v = np.zeros((len(x),len(y),len(t)));

    u[:,:,0]=np.tanh(np.sqrt(X**2+Y**2))*np.cos(m*np.angle(X+1j*Y)-(np.sqrt(X**2+Y**2)));
    v[:,:,0]=np.tanh(np.sqrt(X**2+Y**2))*np.sin(m*np.angle(X+1j*Y)-(np.sqrt(X**2+Y**2)));

    # REACTION-DIFFUSION
    uvt=np.concatenate([np.reshape(np.fft.fft2(u[:,:,0]).T,(N,1)), np.reshape(np.fft.fft2(v[:,:,0]).T,(N,1))]);
    #uvsol=integrate.complex_ode(reaction_diffusion_rhs,uvt[:,0],t,args=(K22,d1,d2,beta,n,N));
    sol=integrate.solve_ivp(lambda t,u: reaction_diffusion_rhs(t,u,K22,d1,d2,beta,n,N),[0,10],uvt[:,0],t_eval=t,method='RK45');
    uvsol = sol.y

    #%%
    for j in range(len(t)-1):
        ut=np.reshape(uvsol[:N,j+1],(n,n));
        vt=np.reshape(uvsol[N:,j+1],(n,n));
        u[:,:,j+1]=np.real(np.fft.ifft2(ut));
        v[:,:,j+1]=np.real(np.fft.ifft2(vt));

    np.savez('reaction_diffusion_big.npz',t=t,x=x,y=y,u=u,v=v)

    for j in np.arange(0,200,10):
        plt.figure()
        plt.pcolormesh(v[:,:,j])
        plt.axis('image')
    return v

# %%
remakeRDData = False
if(remakeRDData is True):
    v = getRDData()
    squareSize = v.shape[0]
    flattenData = np.reshape(v,(squareSize**2,201))
    np.save('data/RDData',flattenData)
else:
    flattenData = np.load('data/RDData.npy')

# %%
print(flattenData[:,0])
# Out:
# [ 0.71061143  0.31770155 -0.13028327 ...  0.85062899  0.53314198
#   0.09338038]

# %%
dataInRD = flattenData[:,0:-1].T
dataOutRD = flattenData[:,1:].T
print(dataInRD.shape)
print(dataOutRD.shape)
# Out:
# (200, 1024)
# (200, 1024)

# %% [markdown]
# ## SVD  data

# %%
u,s,vh = np.linalg.svd(dataInRD)

#do the selection of components by total "energy explained" not variance as variance is for pca

#project onto spatial nodes which are not v. so its columns of u transpose times x to get the data, times x

# just multiply by u not transposed to get the data back

#so to reiterate, you project down by multiply by u transpose and then back up to our space using u not transposed.

# %%
np.sum(s)
energies = s / np.sum(s)
energyXs = np.arange(0,len(s))
plt.clf()
plt.plot(energyXs[0:12],energies[0:12])
plt.xlabel('component number')
plt.ylabel('percentage energy explained')
# Out:
# Text(0, 0.5, 'percentage energy explained')

# %%
numComps = 10

# %%
reducedData = dataInRD.dot(vh[:numComps,:].T)
reducedIn = reducedData[:-1]
reducedOut = reducedData[1:]

# %%
if(os.path.isfile('data/weightsRD.npy')):
    clfRD = np.load('data/weightsRD.npy').flatten()[0]
else:
    clfRD = MLPRegressor(solver='sgd', alpha=1e-5,random_state=123)
    clfRD.fit(reducedIn,reducedOut)
    np.save('data/weightsRD',clfRD)

# %%
print(clfRD.n_iter_)
print(clfRD.n_layers_)
print(clfRD.n_outputs_)
print(clfRD.out_activation_)
print(clfRD.loss_)
# Out:
# 146
# 3
# 10
# identity
# 0.009531843381942054

# %%
# Out:
# -581.2380484926543

# %%
res = np.reshape(reducedIn[0],(-1,1)).T
resBack = res
size = dataInRD.shape[1]
counter = 1
result = np.zeros([200,size])
result[0,:]=resBack.dot(vh[:numComps,:])

while(counter<200):
    resBack = clfRD.predict(resBack)
    result[counter,:]=resBack.dot(vh[:numComps,:])
    counter+=1

# %%
sampleImage = np.reshape(result[0],(squareSize,squareSize))

# %%
plt.figure()
plt.pcolormesh(sampleImage)
plt.axis('image')
# Out:
# (0.0, 32.0, 0.0, 32.0)

# %%
counter = 0
for j in np.arange(0,200,10):
    sampleImage = np.reshape(result[j],(squareSize,squareSize))
    plt.figure()
    plt.pcolormesh(sampleImage)
    plt.axis('image')

# %% [markdown]
# ## Exercise 3,  lorenz equations
#
# so for the plane, try x avg or x is zero, once calculated, go through all data samples and create the lobe and change vectors, if they never change lobes, toss the data, and generate a new one or

# %%
#stolen from https://matplotlib.org/gallery/mplot3d/lorenz_attractor.html
def lorenz(t,xs, r=28):
    b=2.667
    s=10
    '''
    Given:
       x, y, z: a point of interest in three dimensional space
       s, r, b: parameters defining the lorenz attractor
    Returns:
       x_dot, y_dot, z_dot: values of the lorenz attractor's partial
           derivatives at the point x, y, z
    '''
    x_dot = s*(xs[1] - xs[0])
    y_dot = r*xs[0] - xs[0]*xs[2] - xs[1]
    z_dot = xs[0]*xs[1] - b*xs[2]
    return np.array([x_dot, y_dot, z_dot])

# %%
hasGen=True
if(hasGen == False):
    np.random.seed(123)
    numLoops = 300
    counter  =0
    xs=[]
    ys=[]
    zs=[]
    timeEnd=8
    times = np.arange(0,timeEnd,0.01)
    rhos=[10,28,40]
    at = 1*(10**(-11))
    rt = 1*(10**(-10))
    fullInputs =[]
    fullOutputs = []
    rhoCounter = 0
    while(counter<numLoops):
        if(int(counter/100) == 1):
            rhoCounter=1
        elif(int(counter/100)==2):
            rhoCounter=2
        else:
            rhoCounter=0
        inits = 30* np.random.random_sample((3,))
        res = sc.integrate.solve_ivp(lambda t,x: lorenz(t,x,rhos[rhoCounter]),t_span=[0,timeEnd] ,t_eval=times,y0=inits,atol=at,rtol=rt)
        fullLData=res.y
        fullTimes = res.t
        xs.append(fullLData[0,:])
        ys.append(fullLData[1,:])
        zs.append(fullLData[2,:])
        firstInputs = fullLData.T[:-1]
        firstOutputs = fullLData.T[1:]
        fullInputs.append(firstInputs)
        fullOutputs.append(firstOutputs)
        counter+=1

    
    fo = np.array(fullOutputs)
    fi =  np.array(fullInputs)

    fullInputs = np.reshape(fi,(-1,3))
    fullOutputs = np.reshape(fo,(-1,3))
    fullOutputs[1,0]
    rho1 = np.repeat(rhos[0],100*(799))
    rho2 = np.repeat(rhos[1],100*(799))
    rho3 = np.repeat(rhos[2],100*(799))
    allRhos = np.append(rho1,rho2)
    allRhos = np.reshape(np.append(allRhos,rho3),(-1,1))
    fullInputs = np.append(fullInputs,allRhos,axis=1)
    

else:
    fullOutputs=np.load('fullLorenzTrainOut.npy')
    fullInputs=np.load('fullLorenzTrainOut.npy')

# %%
# Out:
# 18.726722415620667

# %%
fullInputs.shape
# Out:
# (239700, 4)

# %%
np.save('fullLorenzTrainIn',fullInputs)
np.save('fullLorenzTrainOut',fullOutputs)

# %%
xs=fullInputs[:,0]
ys=fullInputs[:,1]
zs=fullInputs[:,2]

# %%
fullInputs[0,3]
# Out:
# 10.0

# %%
# %matplotlib notebook
fig = plt.figure()
ax =Axes3D(fig)
#ax = fig.gca(projection='3d')

ax.scatter(xs, ys, zs, s=0.1)
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
ax.set_title("Lorenz Attractor")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
fullInputs[2]
# Out:
# array([18.72672242,  9.05843356,  9.8872764 , 10.        ])

# %%
if(os.path.isfile('data/weightsLorenz.npy')):
    clfLorenz = np.load('data/weightsLorenz.npy').flatten()[0]
else:
    clfLorenz = MLPRegressor(alpha=1e-5,random_state=123,hidden_layer_sizes=(200,300,200))
    res = clfLorenz.fit(fullInputs,fullOutputs)

# %%
# Out:
# MLPRegressor(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(200, 300, 200), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=123, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
np.save('data/weightsLorenz',clfLorenz)

# %%
printNNInfo(clfLorenz)
# Out:
# Num Iters: 39
# numLayers: 5
# Num outputs: 3
# activation layer: identity
# Loss: 0.0015895018685285413

# %%
def predictLorenz(rho,init,numIters):
    nVal = np.reshape(np.append(init,rho),(1,-1))
    preds=[init]
    counter=1
    while counter<numIters:
        nVal = clfLorenz.predict(nVal)
        preds.append(nVal)
        nVal = np.reshape(np.append(nVal,rho),(1,-1))

        counter+=1
    return np.array(preds)

# %%
myxs=[]
myys=[]
myzs=[]
axs=[]
ays=[]
azs=[]
inits = 30* np.random.random_sample((3,))
inits = np.reshape(np.array(inits),(1,-1))
timeEnd=8
times = np.arange(0,timeEnd,0.01)
rhos=[17,35]
at = 1*(10**(-11))
rt = 1*(10**(-10))
rhoCounter = 0    
ares1 = sc.integrate.solve_ivp(lambda t,x: lorenz(t,x,rhos[0]),t_span=[0,timeEnd] ,t_eval=times,y0=inits.flatten(),atol=at,rtol=rt)
mres1 = predictLorenz(rhos[0],inits,len(times))
mres1 = np.reshape(mres1.T,(3,-1))

ares2 = sc.integrate.solve_ivp(lambda t,x: lorenz(t,x,rhos[1]),t_span=[0,timeEnd] ,t_eval=times,y0=inits.flatten(),atol=at,rtol=rt)
mres2 = predictLorenz(rhos[1],inits,len(times))
mres2 = np.reshape(mres2.T,(3,-1))

# %%
fig = plt.figure()
ax =Axes3D(fig)
#ax = fig.gca(projection='3d')

ax.scatter(ares1.y[0], ares1.y[1], ares1.y[2], s=0.1)
ax.scatter(mres1[0], mres1[1], mres1[2], s=0.1)

ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
ax.set_title("Lorenz Attractor")

plt.show()

# %%
fig = plt.figure()
ax =Axes3D(fig)
#ax = fig.gca(projection='3d')

ax.scatter(ares2.y[0], ares2.y[1], ares2.y[2], s=0.1)
ax.scatter(mres2[0], mres2[1], mres2[2], s=0.1)

ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
ax.set_title("Lorenz Attractor")

plt.show()

# %%
fig, axs = plt.subplots(3,2)


axs[0,0].plot(times,mres1[0])
axs[0,0].plot(times,ares1.y[0])

axs[1,0].plot(times,mres1[1])
axs[1,0].plot(times,ares1.y[1])

axs[2,0].plot(times,mres1[2])
axs[2,0].plot(times,ares1.y[2])

axs[0,1].plot(times,mres2[0])
axs[0,1].plot(times,ares2.y[0])

axs[1,1].plot(times,mres2[1])
axs[1,1].plot(times,ares2.y[1])

axs[2,1].plot(times,mres2[2])
axs[2,1].plot(times,ares2.y[2])

# %% [markdown]
# ## Flip Predictions
# Lets assume our flip point is $x=0$

# %%
recalcFlipz =False
if recalcFlipz is True:
    numLoops = 300
    counter  =0
    xs=[]
    ys=[]
    zs=[]
    timeEnd=8
    times = np.arange(0,timeEnd,0.01)
    rhos=28
    at = 1*(10**(-11))
    rt = 1*(10**(-10))
    fullInputs =[]
    fullOutputs = []
    rhoCounter = 0
    flipData=[]
    pointData=[]
    numFlipArr=[]
    while(counter<numLoops):
        inits = 30* np.random.random_sample((3,))
        res = sc.integrate.solve_ivp(lambda t,x: lorenz(t,x,rhos),t_span=[0,timeEnd] ,t_eval=times,y0=inits,atol=at,rtol=rt)
        fullLData=res.y
        xs = fullLData[0,:]
        if((np.min(xs)>0 and np.max(xs)>0) or (np.min(xs)<=0 and np.max(xs)<=0)):
            print('nope')
           #we aint putting this in our data
        else:
            startSign=0
            startPos=0
            numFlips=0
            sepCounter = 1
            endPos=1
            startSign = np.sign(xs[0])
            holdfd=[]
            holdpd=[]
            while(sepCounter<len(xs)):
                if(np.sign(xs[sepCounter])!=startSign):
                    holdfd.append(np.arange(endPos,0,-1))
                    holdpd.append(fullLData[:,startPos:sepCounter].T)
                    startPos=sepCounter
                    endPos=1
                    startSign=np.sign(xs[sepCounter])
                    numFlips+=1
                else:
                    endPos+=1
                sepCounter+=1
            if(numFlips<=1):
                pass
            else:
                numFlipArr.append(numFlips)
                flipData.append(holdfd)
                pointData.append(holdpd)
        counter+=1
    np.save('data/flipArr',numFlipArr)
    np.save('data/flipData',flipData)
    np.save('data/pointData',pointData)
else:
    numFlipArr =np.load('data/flipArr.npy')
    flipData =np.load('data/flipData.npy')
    pointData = np.load('data/pointData.npy')

# %%
flipData[0][1].shape
# Out:
# (150,)

# %%
pointData[0][1].shape
# Out:
# (150, 3)

# %%
toSplit = int(len(numFlipArr)-3)

# %%
lastXIns = []
lastXOuts = []
lastXVIns = []
lastXVOuts = []
counter =0
for x in pointData:
    for y in x:
        for z in y:
            if(counter<toSplit):
                lastXIns.append(z)
            else:
                lastXVIns.append(z)
    counter+=1
counter=0
for x in flipData:
    for y in x:
        for z in y:
            if(counter<toSplit):
                lastXOuts.append(z)
            else:
                lastXVOuts.append(z)
    counter+=1

xTIns = np.array(lastXIns)
xTOuts=np.array(lastXOuts)

xVIns = np.array(lastXVIns)
xVOuts=np.array(lastXVOuts)

# %%
xTIns.shape
# Out:
# (125483, 3)

# %%
xTOuts.shape
# Out:
# (125483,)

# %%
xVIns.shape
# Out:
# (2318, 3)

# %%
xVOuts[-2]
# Out:
# 2

# %%
if(os.path.isfile('data/weightsFlipz.npy')):
    clfFlipz = np.load('data/weightsFlipz.npy').flatten()[0]
else:
    clfFlipz = MLPRegressor(alpha=1e-5,random_state=123,hidden_layer_sizes=(200,300,200))
    clfFlipz.fit(xTIns,xTOuts)

# %%
np.save('data/weightsFlipz',clfFlipz)

# %%
def predictFlip(points,model):
    counter=0
    numIters = len(points)
    preds=[]
    while counter<numIters:
        nVal = model.predict(np.reshape(points[counter],(-1,1)).T)
        preds.append(nVal)
        counter+=1
    return np.array(preds)

# %%
predFLipz = predictFlip(xTIns,clfFlipz)

# %%
predVFLipz = predictFlip(xVIns,clfFlipz)

# %%
plt.plot(np.arange(0,len(predFLipz[0:100]),1),predFLipz[0:100])
plt.xlabel('timestep')
plt.ylabel('steps till the next flip')
plt.title('NN performance on training data')
# Out:
# Text(0.5, 1.0, 'NN performance on training data')

# %%
plt.plot(np.arange(0,len(xTOuts[0:100]),1),xTOuts[0:100])

# %%
plt.plot(np.arange(0,len(predVFLipz[0:100]),1),predVFLipz[0:100])

# %%
plt.plot(np.arange(0,len(xVOuts[0:100]),1),xVOuts[0:100])

# %%
flipPoint = np.mean(xs)
# Out:
# -2.141885844196638

# %%
def createFlipData(flipPlane,rawData):
    startSign = np.sign(rawData)

# %% [markdown]
# for part 2, given x y z, how long until I go to the other plane?
# use tanh activation
